# %% [markdown]
# <a href="https://colab.research.google.com/github/sriharshamutnuru/AgenticAIBootcamp/blob/main/pyddantic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Pydantic Basics: Creating and Using Models
# Pydantic models are the foundation of data validation in Python. They use Python type annotations to define the structure and validate data at runtime. Here's a detailed exploration of basic model creation with several examples.

# %%
from dataclasses import dataclass

@dataclass
class Person():
  name:str
  age:int
  city:str

# %%
person = Person("Harsha",32,"Hyd")

# %%
print(person)
# Out:
# Person(name='Harsha', age=32, city='Hyd')

# %%
person = Person("Harsha",32,45)

# %%
print(person)
# Out:
# Person(name='Harsha', age=32, city=45)

# %%
##pydantic
# !pip install pydantic

# %%
from pydantic import BaseModel

# %%
class Person1(BaseModel):
    name:str
    age:int
    city:str

person=Person1(name="Harsha",age=32,city="Bangalore")
print(person)
# Out:
# name='Harsha' age=32 city='Bangalore'

# %%
person=Person1(name="Harsha",age=32,city=45)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# /tmp/ipython-input-2753538345.py in <cell line: 0>()
# ----> 1 person=Person1(name="Harsha",age=32,city=45)
#
# /usr/local/lib/python3.12/dist-packages/pydantic/main.py in __init__(self, **data)
#     251         # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252         __tracebackhide__ = True
# --> 253         validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254         if self is not validated_self:
#     255             warnings.warn(
#
# ValidationError: 1 validation error for Person1
# city
#   Input should be a valid string [type=string_type, input_value=45, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type

# %% [markdown]
# #### 2. Model with Optional Fields
# Add optional fields using Python's Optional type:

# %%
from typing import Optional
class Employee(BaseModel):
  id:int
  name:str
  department:str
  salary:Optional[float]=None
  is_active:Optional[bool]=True
emp1=Employee(id=1,name="John",department="CS")
print(emp1)
# Out:
# id=1 name='John' department='CS' salary=None is_active=True

# %%
emp2=Employee(id=2,name="Harsha",department="CS",salary="30000")
print(emp2)
# Out:
# id=2 name='Harsha' department='CS' salary=30000.0 is_active=True

# %% [markdown]
# Definition:
# - Optional[type]: Indicates the field can be None
#
# - Default value (= None or = True): Makes the field optional
#
# - Required fields must still be provided
#
# - Pydantic validates types even for optional fields when values are provided

# %%
emp3=Employee(id=2,name="Harsha",department="CS",salary="30000",is_active=1)
print(emp3)
# Out:
# id=2 name='Harsha' department='CS' salary=30000.0 is_active=True

# %%
from typing import List

class Classroom(BaseModel):
    room_number:str
    students: List[str] #List of strings
    capacity:int

# %%
# Create a classroom
classroom = Classroom(
    room_number="A101",
    students=("Alice", "Bob", "Charlie"),
    capacity=30
)
print(classroom)
# Out:
# room_number='A101' students=['Alice', 'Bob', 'Charlie'] capacity=30

# %%
list(("Alice", "Bob", "Charlie"))
# Out:
# ['Alice', 'Bob', 'Charlie']

# %%
# Create a classroom
classroom1 = Classroom(
    room_number="A101",
    students=("Alice", 123, "Charlie"),
    capacity=30
)
print(classroom1)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# /tmp/ipython-input-4198183361.py in <cell line: 0>()
#       1 # Create a classroom
# ----> 2 classroom1 = Classroom(
#       3     room_number="A101",
#       4     students=("Alice", 123, "Charlie"),
#       5     capacity=30
#
# /usr/local/lib/python3.12/dist-packages/pydantic/main.py in __init__(self, **data)
#     251         # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252         __tracebackhide__ = True
# --> 253         validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254         if self is not validated_self:
#     255             warnings.warn(
#
# ValidationError: 1 validation error for Classroom
# students.1
#   Input should be a valid string [type=string_type, input_value=123, input_type=int]
# ...

# %%
try:
    invalid_val=Classroom(room_number="A1",students=["Harsha",123],capacity=30)

except Exception as e:
    print(e)
# Out:
# 1 validation error for Classroom
# students.1
#   Input should be a valid string [type=string_type, input_value=123, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type

# %% [markdown]
# #### 4. Model with Nested Models
# Create complex structures with nested models:

# %%
from pydantic import BaseModel

class Address(BaseModel):
    street:str
    city:str
    zip_code:str

class Customer(BaseModel):
    customer_id:int
    name:str
    address:Address  ## Nested Model

# %%
customer=Customer(customer_id=1,name="Krish",
                  address={"street":"Main street","city":"Boston","zip_code":"02108"})

print(customer)
# Out:
# customer_id=1 name='Krish' address=Address(street='Main street', city='Boston', zip_code='02108')

# %%
customer=Customer(customer_id=1,name="Krish",
                  address={"street":"Main street","city":123,"zip_code":"02108"})

print(customer)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# /tmp/ipython-input-1937616291.py in <cell line: 0>()
# ----> 1 customer=Customer(customer_id=1,name="Krish",
#       2                   address={"street":"Main street","city":123,"zip_code":"02108"})
#       3
#       4 print(customer)
#
# /usr/local/lib/python3.12/dist-packages/pydantic/main.py in __init__(self, **data)
#     251         # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252         __tracebackhide__ = True
# --> 253         validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254         if self is not validated_self:
#     255             warnings.warn(
#
# ValidationError: 1 validation error for Customer
# address.city
#   Input should be a valid string [type=string_type, input_value=123, input_type=int]
# ...

# %% [markdown]
# #### Pydantic Fields: Customization and Constraints
#
# The Field function in Pydantic enhances model fields beyond basic type hints by allowing you to specify validation rules, default values, aliases, and more. Here's a comprehensive tutorial with examples.

# %%
from pydantic import BaseModel,Field

class Item(BaseModel):
    name:str=Field(min_length=2,max_length=50)
    price:float=Field(gt=0,le=10000)  ## greater than 0 and less than or equal to 1000
    quantity:int=Field(ge=0)

item=Item(name="Book", price=100000,quantity=10)
print(item)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# /tmp/ipython-input-1377422794.py in <cell line: 0>()
#       6     quantity:int=Field(ge=0)
#       7
# ----> 8 item=Item(name="Book", price=100000,quantity=10)
#       9 print(item)
#
# /usr/local/lib/python3.12/dist-packages/pydantic/main.py in __init__(self, **data)
#     251         # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252         __tracebackhide__ = True
# --> 253         validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254         if self is not validated_self:
#     255             warnings.warn(
#
# ValidationError: 1 validation error for Item
# price
#   Input should be less than or equal to 10000 [type=less_than_equal, input_value=100000, input_type=int]
# ...

# %%
class User(BaseModel):
    username:str=Field(description="Unique username for the user")
    age:int=Field(default=18,description="User age default to 18 ")
    email:str= Field(default_factory=lambda: "user@example.com",description="Default email address")


# Examples
user1 = User(username="alice")
print(user1)
# Out:
# username='alice' age=18 email='user@example.com'

# %%
user2 = User(username="bob", age=25, email="bob@domain.com")
print(user2)
# Out:
# username='bob' age=25 email='bob@domain.com'

# %%
User.model_json_schema()
# Out:
# {'properties': {'username': {'description': 'Unique username for the user',
#    'title': 'Username',
#    'type': 'string'},
#   'age': {'default': 18,
#    'description': 'User age default to 18 ',
#    'title': 'Age',
#    'type': 'integer'},
#   'email': {'description': 'Default email address',
#    'title': 'Email',
#    'type': 'string'}},
#  'required': ['username'],
#  'title': 'User',
#  'type': 'object'}
